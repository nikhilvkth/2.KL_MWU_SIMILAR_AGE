# %%
import pandas as pd
df1 = pd.read_pickle('/Users/nvalsankulangareth/Age/freestyle_voice_feature_fixed_ic13_train .pkl')
df1 =pd.DataFrame(df1)
df1
# Out:
#                        audspec_lengthL1norm_sma_range_IC13  \
# sample_name
# 1MH004F8NH4_Sample2                               3.941891
# 1MH004F8NH4_Sample3                               3.382757
# 1MH004F8NH4_Sample4                               2.943043
# 1MH004F8NH4_Sample5                               3.452679
# 1MH004F8NH4_Sample6                               3.477017
# ...                                                    ...
# 1MH007405DW_Sample100                             2.245195
# 1MH007405DW_Sample101                             2.355750
# 1MH007405DW_Sample102                             2.045330
# 1MH007405DW_Sample103                             0.714013
# 1MH007405DW_Sample104                             1.174387
#
#                        audspec_lengthL1norm_sma_maxPos_IC13  \
# sample_name
# 1MH004F8NH4_Sample2                                0.187654
# 1MH004F8NH4_Sample3                                0.037143
# ...

# %%
#Add outcome 
hyper_data = pd.read_excel('/Users/nvalsankulangareth/MannWhitney/same_range_of_age/Age_hyper.xlsx')
hd_df = pd.DataFrame(hyper_data)
hd_df = hd_df.iloc[6:,1:]
hd_df = hd_df.reset_index()
hd_df = hd_df.drop(columns = ['index'])
print(hd_df.columns)


hd_df.set_index("Unnamed: 1",inplace=True)
hd_df
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')
#             Unnamed: 2 Unnamed: 3
# Unnamed: 1
# 1MH001PHH5R         22          N
# 1MH001HT8WM         25          N
# 1MH001NTGAO         50          N
# 1MH001NT8QH         57          N
# 1MH001NT8UR         18          N
# ...                ...        ...
# 1MH001RT3K4         48          N
# 1MH004D5EYW         37          N
# 1MH0075Q214         50          N
# 1MH00483JEQ         53          N
# 1MH008CX860         48          Y
#
# [401 rows x 2 columns]

# %%
df_Y=pd.read_csv('/Users/nvalsankulangareth/MannWhitney/same_range_of_age/Hyp_set_agerange')
df_Y=pd.DataFrame(df_Y)
key=[]
for i in range (len(df_Y)):
    key.append(df_Y.iloc[i,0].split('_')[0])
df_Y['key']=key
df_Y
# Out:
#              sample_name  age          key
# 0    1MH004C7U68_Sample1   53  1MH004C7U68
# 1    1MH007AF90H_Sample3   60  1MH007AF90H
# 2    1MH007AG2KR_Sample2   43  1MH007AG2KR
# 3    1MH004F8H64_Sample2   48  1MH004F8H64
# 4    1MH004F8EPW_Sample2   53  1MH004F8EPW
# 5    1MH0025PPCO_Sample1   45  1MH0025PPCO
# 6    1MH007AG2QH_Sample2   35  1MH007AG2QH
# 7    1MH001W7VQ8_Sample2   58  1MH001W7VQ8
# 8    1MH001W6ZK0_Sample2   46  1MH001W6ZK0
# 9    1MH0075PWN4_Sample1   60  1MH0075PWN4
# 10   1MH001PZ3W8_Sample1   43  1MH001PZ3W8
# 11  1MH001W7ZAM_Sample10   47  1MH001W7ZAM
# 12   1MH0075PWFR_Sample1   51  1MH0075PWFR
# 13   1MH0074052M_Sample2   56  1MH0074052M
# 14   1MH007406MD_Sample1   60  1MH007406MD
# 15   1MH001W7Z9D_Sample2   46  1MH001W7Z9D
# 16   1MH001W7WP4_Sample2   49  1MH001W7WP4
# 17   1MH001PHH3R_Sample2   49  1MH001PHH3R
# 18   1MH00740T6H_Sample2   43  1MH00740T6H
# 19   1MH001PHF1W_Sample2   29  1MH001PHF1W
# 20   1MH004F8PRR_Sample2   47  1MH004F8PRR
# ...

# %%
df_N=pd.read_csv('/Users/nvalsankulangareth/MannWhitney/same_range_of_age/NonHyp_subset_agerange')
df_N
# Out:
#              sample_name  age outcome          key  Z-score
# 0    1MH007405KD_Sample7   42       N  1MH007405KD        0
# 1    1MH002M4L7M_Sample2   37       N  1MH002M4L7M       -1
# 2    1MH002M4L6R_Sample2   45       N  1MH002M4L6R        0
# 3    1MH001W7DX8_Sample2   42       N  1MH001W7DX8        0
# 4    1MH007409U4_Sample2   39       N  1MH007409U4       -1
# 5   1MH00740VCD_Sample19   52       N  1MH00740VCD        0
# 6    1MH007406NW_Sample2   39       N  1MH007406NW       -1
# 7    1MH0075PWGM_Sample2   48       N  1MH0075PWGM        0
# 8    1MH001UZ9R0_Sample2   56       N  1MH001UZ9R0        0
# 9    1MH008WTU34_Sample1   58       N  1MH008WTU34        1
# 10   1MH001PHF3D_Sample2   45       N  1MH001PHF3D        0
# 11   1MH0048PA0D_Sample3   49       N  1MH0048PA0D        0
# 12   1MH001Q3CUH_Sample2   59       N  1MH001Q3CUH        1
# 13   1MH001Q3CRM_Sample2   63       N  1MH001Q3CRM        1
# 14   1MH001W6Z3R_Sample2   46       N  1MH001W6Z3R        0
# ...

# %%
#check any hyper and non hyper is marked same for any patients
import pandas as pd
df3_check= pd.DataFrame()
df3_check= pd.DataFrame(pd.concat([df_Y.iloc[:,[1,2]], df_N.iloc[:,[1,3]]], axis=0))
df3_check=df3_check.add_suffix('_col')
#print(df3_check.value_counts())

df3_check
# Out:
#     age_col      key_col
# 0        53  1MH004C7U68
# 1        60  1MH007AF90H
# 2        43  1MH007AG2KR
# 3        48  1MH004F8H64
# 4        53  1MH004F8EPW
# 5        45  1MH0025PPCO
# 6        35  1MH007AG2QH
# 7        58  1MH001W7VQ8
# 8        46  1MH001W6ZK0
# 9        60  1MH0075PWN4
# 10       43  1MH001PZ3W8
# 11       47  1MH001W7ZAM
# 12       51  1MH0075PWFR
# 13       56  1MH0074052M
# 14       60  1MH007406MD
# 15       46  1MH001W7Z9D
# 16       49  1MH001W7WP4
# 17       49  1MH001PHH3R
# 18       43  1MH00740T6H
# 19       29  1MH001PHF1W
# 20       47  1MH004F8PRR
# 21       43  1MH00740UZM
# 22       56  1MH007AG2DM
# 23       40  1MH001QJRDD
# 24       40  1MH001NTD20
# 25       29  1MH001W6XXW
# 26       57  1MH001W7ZP4
# 0        42  1MH007405KD
# 1        37  1MH002M4L7M
# 2        45  1MH002M4L6R
# 3        42  1MH001W7DX8
# 4        39  1MH007409U4
# 5        52  1MH00740VCD
# 6        39  1MH007406NW
# 7        48  1MH0075PWGM
# 8        56  1MH001UZ9R0
# ...

# %%
df1_new = []



for val in df1.index:
    #print(val)
    names = val.split('_')[0] # get the ID
    df1_new.append(names)
df1["key"] = df1_new


df1
# Out:
#                        audspec_lengthL1norm_sma_range_IC13  \
# sample_name
# 1MH004F8NH4_Sample2                               3.941891
# 1MH004F8NH4_Sample3                               3.382757
# 1MH004F8NH4_Sample4                               2.943043
# 1MH004F8NH4_Sample5                               3.452679
# 1MH004F8NH4_Sample6                               3.477017
# ...                                                    ...
# 1MH007405DW_Sample100                             2.245195
# 1MH007405DW_Sample101                             2.355750
# 1MH007405DW_Sample102                             2.045330
# 1MH007405DW_Sample103                             0.714013
# 1MH007405DW_Sample104                             1.174387
#
#                        audspec_lengthL1norm_sma_maxPos_IC13  \
# sample_name
# 1MH004F8NH4_Sample2                                0.187654
# 1MH004F8NH4_Sample3                                0.037143
# ...

# %%
df1_con=pd.DataFrame()
for k in range (0,len(df3_check)):
    name = df3_check.iloc[k,1]
    print(name)
    df1_con = pd.concat([df1_con ,df1.loc[df1['key']== name]], axis =0)
   
    
#df1_df = pd.DataFrame()
#df1_df['name']=df1_new
df1_con
# Out:
# 1MH004C7U68
# 1MH007AF90H
# 1MH007AG2KR
# 1MH004F8H64
# 1MH004F8EPW
# 1MH0025PPCO
# 1MH007AG2QH
# 1MH001W7VQ8
# 1MH001W6ZK0
# 1MH0075PWN4
# 1MH001PZ3W8
# 1MH001W7ZAM
# 1MH0075PWFR
# 1MH0074052M
# 1MH007406MD
# 1MH001W7Z9D
# 1MH001W7WP4
# 1MH001PHH3R
# 1MH00740T6H
# 1MH001PHF1W
# 1MH004F8PRR
# 1MH00740UZM
# 1MH007AG2DM
# 1MH001QJRDD
# 1MH001NTD20
# 1MH001W6XXW
# 1MH001W7ZP4
# 1MH007405KD
# 1MH002M4L7M
# 1MH002M4L6R
# 1MH001W7DX8
# 1MH007409U4
# 1MH00740VCD
# 1MH007406NW
# 1MH0075PWGM
# 1MH001UZ9R0
# 1MH008WTU34
# 1MH001PHF3D
# 1MH0048PA0D
# 1MH001Q3CUH
# 1MH001Q3CRM
# 1MH001W6Z3R
# 1MH00740VQM
# 1MH00740DL4
# 1MH001PZ3TH
# 1MH001Q5CD8
# 1MH002QH2EH
# 1MH001Q5D8M
# 1MH0074074W
# 1MH0025PPC4
# 1MH00740V58
# 1MH001Q3CPH
# 1MH0025PPJH
# 1MH001PZ3WD
#                       audspec_lengthL1norm_sma_range_IC13  \
# sample_name
# 1MH004C7U68_Sample1                              2.408057
# 1MH004C7U68_Sample2                              2.596503
# ...

# %%
#perform MWU whole

# %%
outcome=[]

for val in df1_con.key :
    if val in hd_df.index:# if name is in the hypertension dataframe
        h_val = hd_df.loc[val,"Unnamed: 3"] # getting the hypertension value for the id
        outcome.append(h_val)
df1_con['outcome'] = outcome

# %%
df1_con_N = df1_con.loc[df1_con['outcome']== 'N']
df1_con_N
# Out:
#                       audspec_lengthL1norm_sma_range_IC13  \
# sample_name
# 1MH007405KD_Sample7                              1.829439
# 1MH007405KD_Sample8                              2.252453
# 1MH007405KD_Sample9                              2.385723
# 1MH007405KD_Sample10                             2.130729
# 1MH007405KD_Sample11                             2.129255
# ...                                                   ...
# 1MH001PZ3WD_Sample81                             2.249730
# 1MH001PZ3WD_Sample82                             2.514916
# 1MH001PZ3WD_Sample83                             2.167996
# 1MH001PZ3WD_Sample84                             2.113756
# 1MH001PZ3WD_Sample85                             2.183727
#
#                       audspec_lengthL1norm_sma_maxPos_IC13  \
# sample_name
# 1MH007405KD_Sample7                               0.653938
# 1MH007405KD_Sample8                               0.174033
# 1MH007405KD_Sample9                               0.845272
# ...

# %%
df1_con_Y = df1_con.loc[df1_con['outcome']== 'Y']
df1_con_Y
# Out:
#                       audspec_lengthL1norm_sma_range_IC13  \
# sample_name
# 1MH004C7U68_Sample1                              2.408057
# 1MH004C7U68_Sample2                              2.596503
# 1MH004C7U68_Sample3                              2.438260
# 1MH004C7U68_Sample4                              2.791061
# 1MH004C7U68_Sample5                              2.716742
# ...                                                   ...
# 1MH001W7ZP4_Sample80                             1.463058
# 1MH001W7ZP4_Sample81                             1.855312
# 1MH001W7ZP4_Sample82                             1.604187
# 1MH001W7ZP4_Sample83                             1.707024
# 1MH001W7ZP4_Sample84                             1.297973
#
#                       audspec_lengthL1norm_sma_maxPos_IC13  \
# sample_name
# 1MH004C7U68_Sample1                               0.913596
# 1MH004C7U68_Sample2                               0.113452
# 1MH004C7U68_Sample3                               0.945545
# ...

# %%
df1_con_Nf = df1_con_N.iloc[:,:-2]
df1_con_Nf = df1_con_Nf.astype(float)
df1_con_Nf
# Out:
#                       audspec_lengthL1norm_sma_range_IC13  \
# sample_name
# 1MH007405KD_Sample7                              1.829439
# 1MH007405KD_Sample8                              2.252453
# 1MH007405KD_Sample9                              2.385723
# 1MH007405KD_Sample10                             2.130729
# 1MH007405KD_Sample11                             2.129255
# ...                                                   ...
# 1MH001PZ3WD_Sample81                             2.249730
# 1MH001PZ3WD_Sample82                             2.514916
# 1MH001PZ3WD_Sample83                             2.167996
# 1MH001PZ3WD_Sample84                             2.113756
# 1MH001PZ3WD_Sample85                             2.183727
#
#                       audspec_lengthL1norm_sma_maxPos_IC13  \
# sample_name
# 1MH007405KD_Sample7                               0.653938
# 1MH007405KD_Sample8                               0.174033
# 1MH007405KD_Sample9                               0.845272
# ...

# %%
df1_con_Yf = df1_con_Y.iloc[:,:-2]
df1_con_Yf = df1_con_Yf.astype(float)
df1_con_Yf
# Out:
#                       audspec_lengthL1norm_sma_range_IC13  \
# sample_name
# 1MH004C7U68_Sample1                              2.408057
# 1MH004C7U68_Sample2                              2.596503
# 1MH004C7U68_Sample3                              2.438260
# 1MH004C7U68_Sample4                              2.791061
# 1MH004C7U68_Sample5                              2.716742
# ...                                                   ...
# 1MH001W7ZP4_Sample80                             1.463058
# 1MH001W7ZP4_Sample81                             1.855312
# 1MH001W7ZP4_Sample82                             1.604187
# 1MH001W7ZP4_Sample83                             1.707024
# 1MH001W7ZP4_Sample84                             1.297973
#
#                       audspec_lengthL1norm_sma_maxPos_IC13  \
# sample_name
# 1MH004C7U68_Sample1                               0.913596
# 1MH004C7U68_Sample2                               0.113452
# 1MH004C7U68_Sample3                               0.945545
# ...

# %%
len(df1_con.columns)-1
# Out:
# 6369

# %%
from scipy.stats import mannwhitneyu
list_similar_age =[]


for i in range(0,len(df1_con_Nf.columns)):

    test_a = pd.DataFrame(df1_con_Nf.iloc[:,i])
    test_b = pd.DataFrame(df1_con_Yf.iloc[:,i])
    list_similar_age.append((mannwhitneyu(df1_con_Nf.iloc[:,i], df1_con_Yf.iloc[:,i])))

# %%
len(list_similar_age)
# Out:
# 6368

# %%
list_MWP_similar_age = pd.DataFrame(list_similar_age)
list_MWP_similar_age
